# %% [markdown]
# If not using google colab, the following can be commented out

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install textworld
# !pip install gym==0.21
# Out:
# Collecting textworld
#   Downloading textworld-1.6.1.tar.gz (708 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 708.6/708.6 kB 4.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.10/dist-packages (from textworld) (1.25.2)
# Requirement already satisfied: tqdm>=4.17.1 in /usr/local/lib/python3.10/dist-packages (from textworld) (4.66.2)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from textworld) (1.16.0)
# Requirement already satisfied: networkx>=2 in /usr/local/lib/python3.10/dist-packages (from textworld) (3.3)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from textworld) (10.1.0)
# Collecting tatsu>=5.8.3 (from textworld)
#   Downloading TatSu-5.8.3-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.5/101.5 kB 11.9 MB/s eta 0:00:00
# Collecting hashids>=1.2.0 (from textworld)
#   Downloading hashids-1.3.1-py2.py3-none-any.whl (6.6 kB)
# Collecting jericho>=3.0.3 (from textworld)
#   Downloading jericho-3.1.2.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting mementos>=1.3.1 (from textworld)
#   Downloading mementos-1.3.1-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from textworld) (2.4.0)
# Requirement already satisfied: prompt-toolkit in /usr/local/lib/python3.10/dist-packages (from textworld) (3.0.43)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.0->textworld) (2.22)
# Requirement already satisfied: spacy>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from jericho>=3.0.3->textworld) (3.7.4)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit->textworld) (0.2.13)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld) (6.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld) (2.7.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld) (3.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.1.0->jericho>=3.0.3->textworld) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.1.0->jericho>=3.0.3->textworld) (2.18.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.1.0->jericho>=3.0.3->textworld) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.1.0->jericho>=3.0.3->textworld) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.1.0->jericho>=3.0.3->textworld) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.1.0->jericho>=3.0.3->textworld) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.1.0->jericho>=3.0.3->textworld) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=2.1.0->jericho>=3.0.3->textworld) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=2.1.0->jericho>=3.0.3->textworld) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy>=2.1.0->jericho>=3.0.3->textworld) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy>=2.1.0->jericho>=3.0.3->textworld) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy>=2.1.0->jericho>=3.0.3->textworld) (2.1.5)
# Building wheels for collected packages: textworld, jericho
#   Building wheel for textworld (pyproject.toml) ... done
#   Created wheel for textworld: filename=textworld-1.6.1-cp310-cp310-linux_x86_64.whl size=6723022 sha256=e81f365d1b4d0d1e183e58a955c05efee30f0cd43fcaae67ef4afbbe6409d14e
#   Stored in directory: /root/.cache/pip/wheels/34/ff/fd/806c0a27e57b83e5aa6eae2dcaf74f93afca93936bfeecbf6e
#   Building wheel for jericho (setup.py) ... done
#   Created wheel for jericho: filename=jericho-3.1.2-py3-none-any.whl size=325097 sha256=6dc191871a7f2d48b4ffb69734ce59eaf014bbe79769bca414afc5147f0210b4
#   Stored in directory: /root/.cache/pip/wheels/6b/1d/a7/91e11767b583fe77fae27d292e724d0dc8cd4335dab886adfe
# Successfully built textworld jericho
# Installing collected packages: mementos, tatsu, hashids, jericho, textworld
# Successfully installed hashids-1.3.1 jericho-3.1.2 mementos-1.3.1 tatsu-5.8.3 textworld-1.6.1
# Collecting gym==0.21
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 7.3 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import torch
import torch.nn as nn
import nltk
nltk.download('punkt')
from nltk import word_tokenize
import numpy as np
import random
import pandas as pd
import json
from heapq import nlargest
import time
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
import os
import subprocess
import matplotlib.pyplot as plt
import textworld.gym
from typing import Mapping, Any

# %%
TRAIN_SEED = 0
TEST_SEEDS = [42]

LEVEL = 5
QUEST_LENGTH = ((LEVEL - 1) % 100 + 1)  #horizon
REWARD_SCALE = 1000
HORIZON = 10 #2*QUEST_LENGTH

NUM_EPOCHS = 30 #50

request_infos = textworld.EnvInfos(
    admissible_commands=True,  # All commands relevant to the current state.
    entities=True,              # List of all interactable entities found in the game.
    facts=True
)

COLUMNS = ['Run #', 'Training Loss']
COLUMNS.extend([f'Testing Loss {i}' for i in TEST_SEEDS])
COLUMNS.append(f'Testing Loss {TRAIN_SEED}')
COLUMNS.extend([f'Test Seed {i} Score' for i in TEST_SEEDS])
COLUMNS.append(f'Test Seed {TRAIN_SEED} Score')

COLUMNS.append('Returns')
COLUMNS.append('Take Coin QValue')

# %% [markdown]
# ## Make Coin Collector Game

# %%
def make_game(seed, path):
  if not os.path.exists(path):
    command = ['tw-make', 'tw-coin_collector', '--level', str(LEVEL), '--seed', str(seed), '--output', path]
    subprocess.run(command)

  env_id = textworld.gym.register_game(path, request_infos)
  env = textworld.gym.make(env_id)

  return env_id, env

# %%
TRAIN_ENV = make_game(TRAIN_SEED, f'tw_games/coin_collector_level{LEVEL}_{TRAIN_SEED}_game.ulx')
TEST_ENVS = [make_game(test_seed, f'tw_games/coin_collector_level{LEVEL}_{test_seed}_game.ulx') for test_seed in TEST_SEEDS]
TEST_ENVS.append(TRAIN_ENV)

# %% [markdown]
# ## LSTM-DQN - Count Based
# Counting paper
# Text Embedding: Description + permissable actions
#
# keep a count for the states as we visit them: state --> count dictionary

# %%
class Network(torch.nn.Module):
  def __init__(self, emb_size, action_space, hidden_dim):
    super(Network, self).__init__()

    self.emb = torch.nn.Embedding(emb_size, hidden_dim)
    self.lstm = torch.nn.LSTM(hidden_dim, hidden_dim, num_layers=1)
    self.lstm_hidden_clean = (torch.randn(1, hidden_dim), torch.randn(1, hidden_dim))

    self.dqn = torch.nn.Sequential(
        torch.nn.Linear(emb_size, hidden_dim),
        torch.nn.ReLU(),
        torch.nn.Linear(hidden_dim, action_space)
    )

  def forward(self, input_tensor):
    embeddings = self.emb(input_tensor)
    hidden = self.lstm_hidden_clean
    output, hidden = self.lstm(embeddings, hidden)
    state_rep = torch.mean(output, dim=1) #actions that can be performed from here + observations
    q_vals = self.dqn(state_rep)
    return q_vals

# %%
class TextAgent_Counter_Cumulative():
  def __init__(self, vocab_size, max_num_actions, bonus, im_decay, penalty=0, gamma=0.9, episodic=False):
    self.word_indices = {}
    self.last_word_idx = 0
    self.action_indices = {}
    self.idx_to_action = {}
    self.last_action_idx = 0
    self.model = Network(emb_size=vocab_size+max_num_actions, action_space=max_num_actions, hidden_dim=128)
    self.optimizer = torch.optim.Adam(self.model.parameters(), 0.003)
    self.vocab_size = vocab_size
    self.num_actions = max_num_actions
    self.loss_fcn = torch.nn.MSELoss()

    self.state_counts = {}
    self.bonus = bonus  #1.0 in the paper
    self.im_decay = im_decay  #-1/3 in the paper
    self.penalty = penalty
    self.prev_action = None
    self.prev_state = None
    self.current_state = None

    self.test_mode = False
    self.gamma = gamma

    self.episodic = episodic

  def set_test(self):
    self.test_mode = True
    self.model.eval()

  def set_train(self):
    self.test_mode = False
    self.model.train()

  def vectorize_observation(self, tokens):
    for token in tokens:
      if token not in self.word_indices.keys():
        if not self.test_mode:
          self.word_indices[token] = self.last_word_idx
          self.last_word_idx += 1
        else:
          token = "UNK"
    word_vector = [self.word_indices[token] for token in tokens if token in self.word_indices]
    indices = torch.tensor(word_vector)

    one_hot = torch.nn.functional.one_hot(indices, num_classes=self.vocab_size)
    token_vector = torch.sum(one_hot, dim=0)

    return token_vector

  # This is where "Bootstrapped Q-Learning with Context Relevant Observation Pruning to Generalize in Text-Based Games"
  # could be applied in future work.
  def tokenize_observation(self, observation):
    return word_tokenize(observation)

  def process_observation(self, observation):
    tokens = self.tokenize_observation(observation)
    vector = self.vectorize_observation(observation)
    return vector

  def process_actions(self, actions):
    for action in actions:
      if action not in self.action_indices.keys():
          self.action_indices[action] = self.last_action_idx
          self.idx_to_action[self.last_action_idx] = action
          self.last_action_idx += 1

    action_vec = [self.action_indices[action] for action in actions if action in self.action_indices]
    indices = torch.tensor(action_vec)

    one_hot = torch.zeros(self.num_actions, dtype=int)
    one_hot[indices] = 100

    return one_hot

  def get_qvals(self, obs, infos, done=False):
    action_string = ",".join(infos['admissible_commands'])

    obs_tensor = self.process_observation(obs)
    actions_tensor = self.process_actions(infos['admissible_commands'])

    input_tensor = torch.cat((obs_tensor,actions_tensor), 0)

    q_vals = None
    if self.test_mode:
      with torch.no_grad():
        q_vals = self.model(input_tensor)
    else:
      q_vals = self.model(input_tensor)



    #INTRINSIC REWARD:
    count_key = tuple(input_tensor.detach().numpy())
    self.current_state = count_key

    if not self.test_mode:

      if not self.episodic:
        if count_key not in self.state_counts:
          print("new state")
          self.state_counts[count_key] = 1

        self.state_counts[count_key] += 1     #visited this state
        intrinsic_reward = self.state_counts[count_key]**self.im_decay #+ self.bonus

        return (q_vals, intrinsic_reward)
      else:
        if count_key not in self.state_counts:
          print("new state")
          self.state_counts[count_key] = 1
        else:
          self.state_counts[count_key] = 0

        return (q_vals, self.state_counts[count_key])



    if count_key not in self.state_counts:

        return (q_vals, 0)

    if not self.episodic:
      intrinsic_reward = self.state_counts[count_key]**self.im_decay #+ self.bonus
      return (q_vals, intrinsic_reward)
    else:
      return (q_vals, self.state_counts[count_key])

  def get_max_qval(self, q_vals, infos):

    action_qvals = {}
    for action in infos['admissible_commands']:
      if action=="look" or action=="inventory":
        continue

      idx = self.action_indices[action]
      action_qval = q_vals[idx]

      action_qvals[action] = action_qval


    highest_qval = max(action_qvals.values())
    best_actions = [key for key, value in action_qvals.items() if value == highest_qval]
    selected_action = random.choice(best_actions)


    return selected_action, highest_qval


  def act(self, obs, infos, q_vals, eps_greedy=True):
    if eps_greedy:
      random = np.random.random()
      if random < 0.5:
        idx = np.random.randint(len(infos['admissible_commands']))
        action = infos['admissible_commands'][np.random.randint(len(infos['admissible_commands']))]
        q_idx = self.action_indices[action]
        return action, q_vals[q_idx]


    action, max_val = self.get_max_qval(q_vals, infos)


    return action, max_val

  def get_qval(self, action, q_vals):
    if action in self.action_indices:
      q_idx = self.action_indices[action]
      return q_vals[q_idx].detach().item()
    else:
      return 0

# %%
class TextAgent_PER(TextAgent_Counter_Cumulative):
  def __init__(self, vocab_size, max_num_actions, bonus=1, im_decay=-1.0, penalty=0, per_sample_frequency=0, gamma=0.9):
    super().__init__(vocab_size=vocab_size, max_num_actions=max_num_actions, bonus=bonus, im_decay=im_decay, penalty=penalty)

    self.history = []
    self.history_priority = {}
    self.per_sample_frequency = per_sample_frequency
    self.num_samples = 5  #can do batching
    self.sample_window = 3  #priority sequence experience replay

  def replay(self):
    if len(self.history) == 0:
      return

    experiences = []

    if len(self.history) < self.num_samples:
      experiences = self.history
    else:
      experience_indices = nlargest(self.num_samples, self.history_priority, key=self.history_priority.get)
      experiences = [(self.history[i], i) for i in experience_indices]

    target_qvals = []
    selected_qvals = []

    for ((obs, infos, score, action, next_obs, next_infos, next_score), i) in experiences:
      q_vals, ireward = self.get_qvals(obs, infos)
      next_q_vals, nireward = self.get_qvals(next_obs, next_infos)

      action_idx = self.action_indices[action]

      action_qval = q_vals[action_idx]
      pred_action, pred_qval = self.get_max_qval(q_vals, infos)

      target_qvals.append(action_qval)
      selected_qvals.append(pred_qval)

      reward = score*REWARD_SCALE + nireward

      self.history_priority[i] = action_qval-pred_qval

    return (selected_qvals, target_qvals)

# %%
class TextAgent_PSER(TextAgent_Counter_Cumulative):
  def __init__(self, vocab_size, max_num_actions, bonus, im_decay, penalty=0, per_sample_frequency=0, gamma=0.9):
    super().__init__(vocab_size=vocab_size, max_num_actions=max_num_actions, bonus=bonus, im_decay=im_decay, penalty=penalty)


    self.prev_action = None
    self.prev_state = None
    self.current_state = None

    self.history = []   #contains entire episodes
    self.history_priority = {}  #episode --> return
    self.per_sample_frequency = per_sample_frequency
    self.num_samples = 1  #can do batching
    self.sample_window = 3  #priority sequence experience replay


  def replay(self):


    if len(self.history) == 0:
      return

    experiences = []

    if len(self.history) < self.num_samples:
      experiences = self.history
    else:
      indices = np.arange(len(self.history))

      experience_indices = np.random.choice(indices, self.num_samples)
      experiences = [self.history[i] for i in experience_indices]

    target_qvals = []
    selected_qvals = []
    total_score = 0
    td_errors = []

    for experience in experiences:

      for (obs, infos, score, action, next_obs, next_infos) in experience:

        q_vals, ireward = self.get_qvals(obs, infos)
        pred_action, pred_q_val = self.act(obs, infos, q_vals)

        action_idx = self.action_indices[action]
        action_qval = q_vals[action_idx]

        next_q_vals, nireward = self.get_qvals(next_obs, next_infos)
        next_action, next_action_qval = self.get_max_qval(next_q_vals, infos)

        reward = score*REWARD_SCALE + nireward

        total_score+=reward

        target_qvals.append(action_qval)
        selected_qvals.append(pred_q_val)
        td_error = action_qval - pred_q_val
        td_errors.append(td_error)

      self.history_priority[i] = total_score

    return (selected_qvals, target_qvals, td_errors)

# %% [markdown]
# ### Training

# %%
def test(agent, max_steps, env):
  # put model into eval
  agent.set_test()

  obs, infos = env.reset()

  done = False
  obs, score, done, infos = env.step('look')
  nb_moves = 0

  actions, observations = [], [obs]
  selected_qvals, target_qvals = [], []

  running_loss = 0.0
  while not done and nb_moves < max_steps:
    q_values, _ = agent.get_qvals(obs, infos, score)
    action, value = agent.get_max_qval(q_values, infos)

    obs, score, done, infos = env.step(action)

    next_q_values, _ = agent.get_qvals(obs, infos, score)
    _, next_value = agent.get_max_qval(next_q_values, infos)

    selected_qvals.append(value)
    target_qvals.append(score*REWARD_SCALE + agent.gamma * next_value)

    nb_moves += 1
    actions.append(action)
    observations.append(obs)

  agent.set_train()

  return 0, score


def conduct_tests(agent, max_steps):
  scores = []
  test_losses = []
  for env_id, env in TEST_ENVS:
    test_loss, score = test(agent, max_steps, env)
    scores.append(score)
    test_losses.append(score*REWARD_SCALE)
    break

  test_loss, score = test(agent, max_steps, TRAIN_ENV[1])
  scores.append(score)
  test_losses.append(score*REWARD_SCALE)

  return test_losses, scores

# %% [markdown]
# ###### Train Vanilla

# %%
def train(env, name, epochs=100, horizon=40, vocab_size=10000, max_num_actions=1000, gamma=0.9, episodic=False):
  agent = TextAgent_Counter_Cumulative(vocab_size=vocab_size, max_num_actions=max_num_actions, bonus=1, im_decay=-1.0, penalty=0, episodic=episodic)
  training_data = []

  for episode in range(epochs):
    print("EPISODE #:", episode)
    # env = textworld.gym.make(env_id)
    obs, infos = env.reset()

    done = False
    score = 0
    obs, score, done, infos = env.step("look")    #don't want the first "here is your task for today" line
    nb_moves = 0
    actions_taken = []
    observations = [obs]
    state_infos = [infos]
    total_score = 0
    selected_qvals = []
    target_qvals = []

    q_vals, i_reward = agent.get_qvals(obs, infos)

    while nb_moves<horizon and not done:
        infos['admissible_commands'].remove('look')
        infos['admissible_commands'].remove('inventory')
        if 'examine coin' in infos['admissible_commands']:
            infos['admissible_commands'].remove('examine coin')


        action, action_qval = agent.act(obs, infos, q_vals, True)

        obs, score, done, infos = env.step(action)

        next_qvals, next_i_reward = agent.get_qvals(obs, infos, done)
        next_action, next_action_qval = agent.get_max_qval(next_qvals, infos)

        total_score += score*REWARD_SCALE+next_i_reward    #technically this game ends when score is 1 so not required

        selected_qvals.append(action_qval)
        target_qvals.append(next_i_reward+score*REWARD_SCALE+gamma*next_action_qval)

        nb_moves += 1
        state_infos.append(infos)
        actions_taken.append(action)
        observations.append(obs)

        agent.prev_state = agent.current_state
        agent.prev_action = action

        q_vals = next_qvals

    loss = agent.loss_fcn(torch.stack(selected_qvals), torch.stack(target_qvals))
    loss.backward()
    agent.optimizer.step()
    agent.optimizer.zero_grad()

    scores, losses = conduct_tests(agent, horizon)

    row = [name, loss.detach().item()]
    row.extend(scores)
    row.extend(losses)
    row.append(total_score)
    take_coin_val = agent.get_qval('take coin', q_vals)
    row.append(take_coin_val)

    training_data.append(row)

  return agent, training_data


  # creating Textworld environment & getting additional infos: https://github.com/microsoft/TextWorld/blob/main/notebooks/Playing%20text-based%20games%20with%20TextWorld.ipynb

# %% [markdown]
# ###### Train PER

# %%
def train_per(env, name, epochs=100, horizon=40, vocab_size=10000, max_num_actions=1000, gamma=0.9):
  agent = TextAgent_PER(vocab_size=vocab_size, max_num_actions=max_num_actions, bonus=1, im_decay=-1.0, penalty=0, per_sample_frequency=5, gamma=gamma)
  move_index = 0
  training_data = []

  for episode in range(epochs):
    print("EPISODE #:", episode)
    obs, infos = env.reset()

    done = False
    score = 0
    obs, score, done, infos = env.step("look")    #don't want the first "here is your task for today" line
    nb_moves = 0
    actions_taken = []
    observations = [obs]
    state_infos = [infos]
    total_score = 0
    selected_qvals = []
    target_qvals = []

    q_vals, i_reward = agent.get_qvals(obs, infos, score)

    while nb_moves<horizon and not done:
        infos['admissible_commands'].remove('look')
        infos['admissible_commands'].remove('inventory')
        if 'examine coin' in infos['admissible_commands']:
            infos['admissible_commands'].remove('examine coin')

        action, action_qval = agent.act(obs, infos, q_vals)
        next_obs, next_score, done, next_infos = env.step(action)

        next_qvals, next_i_reward = agent.get_qvals(next_obs, next_infos, done)
        next_action, next_action_qval = agent.get_max_qval(next_qvals, next_infos)

        reward = next_i_reward+score*REWARD_SCALE

        selected_qvals.append(action_qval)
        target_qvals.append(reward+gamma*next_action_qval)


        experience = (obs, infos, score, action, next_obs, next_infos, next_score)
        agent.history_priority[len(agent.history)] = reward+gamma*next_action_qval-action_qval  #zero-indexed
        agent.history.append(experience)


        move_index += 1
        total_score += next_score*REWARD_SCALE+next_i_reward    #technically this game ends when score is 1 so not required
        nb_moves += 1
        state_infos.append(infos)
        actions_taken.append(action)
        observations.append(obs)

        agent.prev_state = agent.current_state
        agent.prev_action = action

        q_vals = next_qvals
        q_vals = next_qvals
        obs = next_obs
        infos = next_infos
        score = next_score


        if move_index%agent.per_sample_frequency == 0:
           selected, target = agent.replay()
           selected_qvals.extend(selected)
           target_qvals.extend(target)


    loss = agent.loss_fcn(torch.stack(selected_qvals), torch.stack(target_qvals))
    loss.backward()
    agent.optimizer.step()
    agent.optimizer.zero_grad()

    scores, losses = conduct_tests(agent, horizon)

    row = [name, loss.detach().item()]
    row.extend(scores)
    row.extend(losses)
    row.append(total_score)
    take_coin_val = agent.get_qval('take coin', q_vals)
    row.append(take_coin_val)

    training_data.append(row)

  return agent, training_data

# %% [markdown]
# ###### Train PSER

# %%
def train_pser(env, name, epochs=100, horizon=40, vocab_size=10000, max_num_actions=1000, gamma=0.9):
  agent = TextAgent_PSER(vocab_size=vocab_size, max_num_actions=max_num_actions, bonus=1, im_decay=-1.0, penalty=0, per_sample_frequency=3, gamma=gamma)
  move_index = 0
  training_data = []
  episode = 0
  while episode < epochs:
    print("EPISODE #:", episode)
    selected_qvals = []
    target_qvals = []
    total_score = 0
    obs, infos = env.reset()
    done = False

    if move_index%agent.per_sample_frequency == 0 and episode>0 and len(agent.history) > 0:
      selected, target, errors = agent.replay()

      selected_tensor = torch.stack(selected)
      target_tensor = torch.stack(target)
      errors_tensor = torch.stack(errors)

      loss = agent.loss_fcn(selected_tensor, target_tensor)

      loss.backward()
      agent.optimizer.step()
      agent.optimizer.zero_grad()
      move_index+=1
      continue
    else:
      score = 0
      obs, score, done, infos = env.step("look")    #don't want the first "here is your task for today" line
      nb_moves = 0
      actions_taken = []
      observations = [obs]
      state_infos = [infos]


      q_vals, i_reward = agent.get_qvals(obs, infos)

      episode_experience = []
      while nb_moves<horizon and not done:
          infos['admissible_commands'].remove('look')
          infos['admissible_commands'].remove('inventory')
          if 'examine coin' in infos['admissible_commands']:
              infos['admissible_commands'].remove('examine coin')

          action, action_qval = agent.act(obs, infos, q_vals)

          next_obs, next_score, done, next_infos = env.step(action)

          next_qvals, next_i_reward = agent.get_qvals(next_obs, next_infos, done)
          next_action, next_action_qval = agent.get_max_qval(next_qvals, next_infos)

          reward = next_i_reward+score*REWARD_SCALE

          selected_qvals.append(action_qval)
          target_qvals.append(reward+gamma*next_action_qval)


          experience = (obs, infos, next_score, action, next_obs, next_infos)
          episode_experience.append(experience)


          nb_moves += 1
          move_index += 1
          state_infos.append(next_infos)
          actions_taken.append(action)
          observations.append(next_obs)
          total_score += next_score*REWARD_SCALE+next_i_reward    #technically this game ends when score is 1 so not required
          agent.prev_state = agent.current_state
          agent.prev_action = action

          q_vals = next_qvals
          obs = next_obs
          infos = next_infos
          score = next_score




      # only adding successful plays
      if score>0:
        agent.history.append(episode_experience)
        agent.history_priority[len(agent.history)-1] = total_score  #zero-indexed


    loss = agent.loss_fcn(torch.stack(selected_qvals), torch.stack(target_qvals))

    loss.backward()
    agent.optimizer.step()
    agent.optimizer.zero_grad()


    scores, losses = conduct_tests(agent, horizon)

    row = [name, loss.detach().item()]
    row.extend(scores)
    row.extend(losses)
    row.append(total_score)
    take_coin_val = agent.get_qval('take coin', q_vals)
    row.append(take_coin_val)

    training_data.append(row)
    episode+=1


  return agent, training_data

# %% [markdown]
# #### Level 5

# %% [markdown]
# Paths specified for saving data below should be modified (provided paths are applicable to our directory)

# %% [markdown]
# ###### count_cumulative
# - lr = 0.003
# - gamma = 0.9
# - num epochs = 10
# - trained 10 times (10 diff agents basically)
# - seed 0 = train
# - seed 42 = test
# - bonus = 1
# - intrinsic decay = -1.0
# - horizon = 30

# %%
print(TRAIN_ENV[0])
data_cumulative = []
for i in range(5):
  print("ITER: ", i)
  trained_agent, training_data = train(TRAIN_ENV[1], str(i), NUM_EPOCHS, HORIZON, 10000, 1000, 0.9)
  data_cumulative.extend(training_data)
# Out:
# tw-v0
# ITER:  0
# EPISODE #: 0
# new state
# new state
# new state
# new state
# new state
# new state
# 10003.166666666666
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 0 -0.022285297513008118
# EPISODE #: 1
# new state
# 2.3345238095238092
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 1 -7.634833812713623
# EPISODE #: 2
# 1.1912448662448665
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 2 -16.974946975708008
# EPISODE #: 3
# 10001.662337662337
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 3 -23.345218658447266
# EPISODE #: 4
# 1.041812251216276
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 4 -9.088287353515625
# EPISODE #: 5
# 1.0609057609057608
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 5 -2.1701748371124268
# EPISODE #: 6
# 0.8068652823448219
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 6 1.0065937042236328
# EPISODE #: 7
# 0.5187694904074214
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 7 2.1710424423217773
# EPISODE #: 8
# 0.42118590439211134
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 8 2.185394525527954
# EPISODE #: 9
# 0.63251637622347
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 9 1.3906948566436768
# EPISODE #: 10
# 0.3180361107062005
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 10 0.5134677290916443
# EPISODE #: 11
# 0.6820770651660438
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 11 0.7269021272659302
# EPISODE #: 12
# 0.298127445786257
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 12 2.152427911758423
# EPISODE #: 13
# 0.4349048323302396
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 13 3.353756904602051
# EPISODE #: 14
# 0.2438388206485788
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 14 4.272772789001465
# EPISODE #: 15
# 0.23199557302436385
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 15 4.903946399688721
# EPISODE #: 16
# new state
# 10000.701012334759
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 16 5.3102617263793945
# EPISODE #: 17
# 0.40864347962838676
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 17 6.2615156173706055
# EPISODE #: 18
# 0.2248148000111184
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 18 6.772511959075928
# EPISODE #: 19
# 0.18134752426450704
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 19 7.0507426261901855
# EPISODE #: 20
# 10000.491033352613
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 20 7.181392192840576
# EPISODE #: 21
# 10000.440076263605
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 21 15.413092613220215
# EPISODE #: 22
# 0.2580585677204045
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 22 30.725086212158203
# EPISODE #: 23
# 10000.385082783967
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 23 48.6619758605957
# EPISODE #: 24
# 10000.329246809835
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 24 79.02954864501953
# EPISODE #: 25
# 10000.290630284748
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 25 132.04286193847656
# EPISODE #: 26
# 10000.355647918692
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 26 228.25746154785156
# EPISODE #: 27
# new state
# 10000.701972118617
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 27 423.5460205078125
# EPISODE #: 28
# 10000.251869787462
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 28 724.1348266601562
# EPISODE #: 29
# 10000.500526840782
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 29 1005.7820434570312
# ITER:  1
# EPISODE #: 0
# new state
# new state
# new state
# new state
# new state
# 3.5666666666666673
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 0 -0.00021583586931228638
# EPISODE #: 1
# new state
# 2.5690476190476192
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 1 -5.198058605194092
# EPISODE #: 2
# 1.5301587301587303
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 2 -1.6780126094818115
# EPISODE #: 3
# 0.9948162948162947
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 3 1.6012216806411743
# EPISODE #: 4
# 0.7215852559892808
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 4 2.925039529800415
# EPISODE #: 5
# 0.5771654070567114
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 5 1.5795507431030273
# EPISODE #: 6
# 0.5460013029053277
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 6 0.7850073575973511
# EPISODE #: 7
# 0.5092017679890679
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 7 0.2596319615840912
# EPISODE #: 8
# 0.4268246652728077
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 8 0.0010819556191563606
# EPISODE #: 9
# 0.47834246563829136
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 9 -0.6306445598602295
# EPISODE #: 10
# 0.6463312054275052
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 10 -1.0911251306533813
# EPISODE #: 11
# 0.35788341400551626
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 11 -1.222263216972351
# EPISODE #: 12
# new state
# 10000.864699145248
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 12 -1.225225567817688
# EPISODE #: 13
# 0.29960391051145446
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 13 -0.04080362245440483
# EPISODE #: 14
# 0.27406238278116163
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 14 -0.2663218080997467
# EPISODE #: 15
# 0.2522375987701489
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 15 -0.6025186777114868
# EPISODE #: 16
# 0.283810319995183
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 16 -1.0366790294647217
# EPISODE #: 17
# 0.38391678212934166
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 17 -1.5835022926330566
# EPISODE #: 18
# 0.232108502149577
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 18 -2.1827430725097656
# EPISODE #: 19
# 0.3388452720795675
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 19 -2.8042962551116943
# EPISODE #: 20
# 0.1869397329908276
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 20 -3.500772714614868
# EPISODE #: 21
# 0.2961899016458472
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 21 -4.229988098144531
# EPISODE #: 22
# 0.17548893916997998
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 22 -4.843920707702637
# EPISODE #: 23
# new state
# 10000.82403248331
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 23 -5.4481682777404785
# EPISODE #: 24
# 0.38985040368930546
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 24 0.8114142417907715
# EPISODE #: 25
# 0.2740351179966195
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 25 4.576145648956299
# EPISODE #: 26
# 0.14730968826380025
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 26 6.801915645599365
# EPISODE #: 27
# 0.14987977599081287
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 27 8.027994155883789
# EPISODE #: 28
# new state
# 10000.607862235525
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 28 8.555704116821289
# EPISODE #: 29
# 10000.465293880536
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 29 13.656557083129883
# ITER:  2
# EPISODE #: 0
# new state
# new state
# new state
# new state
# new state
# 3.566666666666667
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 0 -0.08768545836210251
# EPISODE #: 1
# new state
# 2.2857142857142856
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 1 -2.626940965652466
# EPISODE #: 2
# new state
# 10001.255555555555
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 2 -0.3303304612636566
# EPISODE #: 3
# 1.282117882117882
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 3 -2.969339609146118
# EPISODE #: 4
# 0.8065308659348908
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 4 -6.5830302238464355
# EPISODE #: 5
# 0.6277356701269744
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 5 -10.952012062072754
# EPISODE #: 6
# new state
# 10001.370952380952
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 6 -14.492814064025879
# EPISODE #: 7
# new state
# 10001.229229512317
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 7 -4.087032794952393
# EPISODE #: 8
# 10000.762073112073
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 8 2.817772150039673
# EPISODE #: 9
# 10000.641281004235
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 9 7.798670768737793
# EPISODE #: 10
# 0.5551709767672766
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 10 14.2537841796875
# EPISODE #: 11
# 0.4601551478405699
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 11 19.860145568847656
# EPISODE #: 12
# 10000.56034328159
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 12 25.26166534423828
# EPISODE #: 13
# 0.3642620092279249
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 13 36.02101135253906
# EPISODE #: 14
# 10000.519477136491
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 14 46.83366012573242
# EPISODE #: 15
# 10000.646782187736
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 15 63.781856536865234
# EPISODE #: 16
# 10000.409236552454
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 16 87.14579772949219
# EPISODE #: 17
# 10000.369318597004
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 17 118.70417022705078
# EPISODE #: 18
# 10000.397009470455
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 18 160.02940368652344
# EPISODE #: 19
# 10000.341044121045
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 19 211.5868377685547
# EPISODE #: 20
# 10000.30225891526
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 20 276.4508056640625
# EPISODE #: 21
# 10000.273443223443
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 21 356.08892822265625
# EPISODE #: 22
# 10000.308693308003
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 22 453.2521667480469
# EPISODE #: 23
# 10000.285657577364
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 23 571.9851684570312
# EPISODE #: 24
# 10000.276025785808
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 24 712.9795532226562
# EPISODE #: 25
# 0.2447174379427419
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 25 873.9207763671875
# EPISODE #: 26
# 10000.232464871195
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 26 1023.7246704101562
# EPISODE #: 27
# 0.2442669617660679
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 27 1187.84375
# EPISODE #: 28
# 0.23110075961662024
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 28 1337.7921142578125
# EPISODE #: 29
# 10000.232999601818
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 29 1468.85400390625
# ITER:  3
# EPISODE #: 0
# new state
# new state
# new state
# new state
# 3.2333333333333334
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 0 0.08230002224445343
# EPISODE #: 1
# new state
# new state
# new state
# 10001.809523809523
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 1 2.878636598587036
# EPISODE #: 2
# 10001.267857142857
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 2 17.482397079467773
# EPISODE #: 3
# 0.9726301476301477
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 3 37.96428298950195
# EPISODE #: 4
# new state
# 10001.686446886446
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 4 57.01397705078125
# EPISODE #: 5
# new state
# 10001.354656862744
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 5 82.8222885131836
# EPISODE #: 6
# 1.1357845371003266
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 6 114.46935272216797
# EPISODE #: 7
# 0.6470853838807129
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 7 144.18309020996094
# EPISODE #: 8
# 0.7947931697931697
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 8 171.52244567871094
# EPISODE #: 9
# 0.6600356115648469
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 9 196.2167205810547
# EPISODE #: 10
# 0.5018349881371702
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 10 218.5735321044922
# EPISODE #: 11
# 0.5867586689848353
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 11 239.13070678710938
# EPISODE #: 12
# 10000.688169328652
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 12 257.23095703125
# EPISODE #: 13
# 0.43702197491652295
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 13 286.7258605957031
# EPISODE #: 14
# 10000.546297454386
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 14 314.24835205078125
# EPISODE #: 15
# 0.41068530884320353
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 15 351.48150634765625
# EPISODE #: 16
# 10000.396276167472
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 16 386.20391845703125
# EPISODE #: 17
# 10000.51620788123
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 17 431.1822509765625
# EPISODE #: 18
# 10000.533273997205
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 18 484.1142578125
# EPISODE #: 19
# 10000.322124861574
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 19 545.6279907226562
# EPISODE #: 20
# 10000.284759358288
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 20 614.7953491210938
# EPISODE #: 21
# 10000.257200159886
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 21 691.8087768554688
# EPISODE #: 22
# 10000.365918042242
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 22 776.909423828125
# EPISODE #: 23
# 10000.230617008474
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 23 867.525390625
# EPISODE #: 24
# 0.21207539919053206
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 24 966.7420043945312
# EPISODE #: 25
# 0.2887190560775965
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 25 1059.90185546875
# EPISODE #: 26
# 0.2530628243413238
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 26 1146.5498046875
# EPISODE #: 27
# 0.2581898502719766
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 27 1227.5816650390625
# EPISODE #: 28
# 10000.320111330559
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 28 1303.61376953125
# EPISODE #: 29
# 0.1833505951393678
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 29 1388.6715087890625
# ITER:  4
# EPISODE #: 0
# new state
# new state
# new state
# new state
# new state
# 3.8333333333333335
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 0 0.04135807976126671
# EPISODE #: 1
# new state
# 2.219047619047619
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 1 -0.27558714151382446
# EPISODE #: 2
# 1.7789682539682539
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 2 -0.8723185658454895
# EPISODE #: 3
# new state
# 10001.179797979798
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 3 0.06528481841087341
# EPISODE #: 4
# 10000.994022644023
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 4 -0.5646526217460632
# EPISODE #: 5
# 10000.830194805194
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 5 4.190247058868408
# EPISODE #: 6
# 10000.710790598292
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 6 17.869457244873047
# EPISODE #: 7
# 0.6685701553348612
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 7 40.164100646972656
# EPISODE #: 8
# 0.5176349965823649
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 8 63.12395477294922
# EPISODE #: 9
# 0.4348144045970132
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 9 86.08472442626953
# EPISODE #: 10
# 0.5519076284368638
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 10 108.33891296386719
# EPISODE #: 11
# 0.5755294419254374
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 11 127.8310546875
# EPISODE #: 12
# 10000.413974682724
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 12 142.1904754638672
# EPISODE #: 13
# 0.45872436782066767
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 13 184.08447265625
# EPISODE #: 14
# new state
# 10000.779806653945
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 14 226.29458618164062
# EPISODE #: 15
# 0.2948509807793958
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 15 294.46832275390625
# EPISODE #: 16
# 10000.627185956393
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 16 364.6859130859375
# EPISODE #: 17
# 10000.361202507782
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 17 462.6794128417969
# EPISODE #: 18
# new state
# 10000.625358851674
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 18 586.6400146484375
# EPISODE #: 19
# 10000.522191240367
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 19 738.1220703125
# EPISODE #: 20
# 10000.449378099505
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 20 920.8818969726562
# EPISODE #: 21
# 10000.449563958451
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 21 1119.937744140625
# EPISODE #: 22
# 0.2487478431860795
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 22 1332.578125
# EPISODE #: 23
# 10000.295432607336
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 23 1522.8179931640625
# EPISODE #: 24
# 0.25523212635762715
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 24 1720.65087890625
# EPISODE #: 25
# 10000.344107744108
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 25 1888.7364501953125
# EPISODE #: 26
# 10000.347916576075
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 26 2082.87841796875
# EPISODE #: 27
# 10000.253903511453
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 27 2291.197265625
# EPISODE #: 28
# 10000.310925320384
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 28 2512.42236328125
# EPISODE #: 29
# 10000.281229689199
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 29 2739.40625

# %%
df = pd.DataFrame(data_cumulative, columns=COLUMNS)
print(df)

df.to_csv("/content/drive/MyDrive/CS 394R - 2024/Data/cumulative_5_long.csv")
#a = df.to_csv()
# Out:
#     Run #  Training Loss  Testing Loss 42  Testing Loss 0  Test Seed 42 Score  \
# 0       0   1.428744e+07                0               0                   0
# 1       0   6.835796e+00                0               0                   0
# 2       0   4.655633e+00                0               0                   0
# 3       0   1.438705e+07                0               0                   0
# 4       0   2.567449e+01                0               0                   0
# ..    ...            ...              ...             ...                 ...
# 145     4   1.134413e+07                0            1000                   0
# 146     4   6.095252e+06                0            1000                   0
# 147     4   7.651730e+06                0            1000                   0
# 148     4   5.939365e+06                0            1000                   0
# 149     4   8.220956e+06                0            1000                   0
#
#      Test Seed 0 Score       Returns  Take Coin QValue
# 0                    0  10003.166667         -0.022285
# 1                    0      2.334524         -7.634834
# 2                    0      1.191245        -16.974947
# 3                    0  10001.662338        -23.345219
# 4                    0      1.041812         -9.088287
# ..                 ...           ...               ...
# 145                  1  10000.344108       1888.736450
# 146                  1  10000.347917       2082.878418
# 147                  1  10000.253904       2291.197266
# 148                  1  10000.310925       2512.422363
# 149                  1  10000.281230       2739.406250
#
# [150 rows x 8 columns]

# %% [markdown]
# ###### count_episodic

# %%
print(TRAIN_ENV[0])
data = []
for i in range(5):
  print("ITER: ", i)
  trained_agent, training_data = train(TRAIN_ENV[1], str(i), NUM_EPOCHS, HORIZON, 10000, 1000, 0.9, True)
  data.extend(training_data)
# Out:
# tw-v0
# ITER:  0
# EPISODE #: 0
# new state
# new state
# new state
# new state
# 3
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 0 0.01448189839720726
# EPISODE #: 1
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 1 -1.0725001096725464
# EPISODE #: 2
# new state
# 1
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 2 0.14551924169063568
# EPISODE #: 3
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 3 -0.02266911044716835
# EPISODE #: 4
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 4 -0.07353532314300537
# EPISODE #: 5
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 5 0.04824645444750786
# EPISODE #: 6
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 6 -0.10119350254535675
# EPISODE #: 7
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 7 -0.07181841135025024
# EPISODE #: 8
# new state
# new state
# 10002
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 8 -0.09345363080501556
# EPISODE #: 9
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 9 0.40678513050079346
# EPISODE #: 10
# new state
# 10001
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 10 1.0318577289581299
# EPISODE #: 11
# new state
# 10001
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 11 5.047204971313477
# EPISODE #: 12
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 12 13.016792297363281
# EPISODE #: 13
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 13 27.080249786376953
# EPISODE #: 14
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 14 48.20793151855469
# EPISODE #: 15
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 15 75.38633728027344
# EPISODE #: 16
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 16 108.65991973876953
# EPISODE #: 17
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 17 149.1932373046875
# EPISODE #: 18
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 18 190.4268798828125
# EPISODE #: 19
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 19 244.6374969482422
# EPISODE #: 20
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 20 300.2737731933594
# EPISODE #: 21
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 21 376.4469299316406
# EPISODE #: 22
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 22 457.5111083984375
# EPISODE #: 23
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 23 569.4735717773438
# EPISODE #: 24
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 24 687.9406127929688
# EPISODE #: 25
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 25 845.3689575195312
# EPISODE #: 26
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 26 1046.7847900390625
# EPISODE #: 27
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 27 1283.6763916015625
# EPISODE #: 28
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 28 1501.9443359375
# EPISODE #: 29
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 29 1742.105224609375
# ITER:  1
# EPISODE #: 0
# new state
# new state
# new state
# new state
# new state
# 4
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 0 0
# EPISODE #: 1
# new state
# 1
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 1 -0.7352837920188904
# EPISODE #: 2
# new state
# 10001
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 2 0.6410915851593018
# EPISODE #: 3
# new state
# 10001
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 3 4.882680892944336
# EPISODE #: 4
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 4 12.651191711425781
# EPISODE #: 5
# new state
# 10001
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 5 21.31741714477539
# EPISODE #: 6
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 6 33.61533737182617
# EPISODE #: 7
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 7 51.213409423828125
# EPISODE #: 8
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 8 68.9885025024414
# EPISODE #: 9
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 9 86.13114929199219
# EPISODE #: 10
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 10 102.15306854248047
# EPISODE #: 11
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 11 116.53314971923828
# EPISODE #: 12
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 12 140.2942657470703
# EPISODE #: 13
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 13 171.6431427001953
# EPISODE #: 14
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 14 202.10496520996094
# EPISODE #: 15
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 15 229.77001953125
# EPISODE #: 16
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 16 264.75390625
# EPISODE #: 17
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 17 305.55059814453125
# EPISODE #: 18
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 18 349.98675537109375
# EPISODE #: 19
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 19 398.5658264160156
# EPISODE #: 20
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 20 443.4209289550781
# EPISODE #: 21
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 21 494.38262939453125
# EPISODE #: 22
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 22 550.9071655273438
# EPISODE #: 23
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 23 613.26025390625
# EPISODE #: 24
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 24 681.71923828125
# EPISODE #: 25
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 25 756.08740234375
# EPISODE #: 26
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 26 826.6673583984375
# EPISODE #: 27
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 27 905.0984497070312
# EPISODE #: 28
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 28 991.6759033203125
# EPISODE #: 29
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 29 1071.780517578125
# ITER:  2
# EPISODE #: 0
# new state
# new state
# new state
# new state
# new state
# new state
# 5
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 0 0.038373932242393494
# EPISODE #: 1
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 1 -0.03428451344370842
# EPISODE #: 2
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 2 0.5086370706558228
# EPISODE #: 3
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 3 -0.31732872128486633
# EPISODE #: 4
# new state
# 10001
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 4 -0.08349280059337616
# EPISODE #: 5
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 5 0.9678474068641663
# EPISODE #: 6
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 6 0.20729322731494904
# EPISODE #: 7
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 7 1.128054141998291
# EPISODE #: 8
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 8 2.1130998134613037
# EPISODE #: 9
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 9 2.907371997833252
# EPISODE #: 10
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 10 3.6093764305114746
# EPISODE #: 11
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 11 8.63056468963623
# EPISODE #: 12
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 12 18.38251304626465
# EPISODE #: 13
# new state
# 10001
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 13 29.514911651611328
# EPISODE #: 14
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 14 47.64210510253906
# EPISODE #: 15
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 15 67.92868041992188
# EPISODE #: 16
# new state
# 10001
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 16 89.62110900878906
# EPISODE #: 17
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 17 124.7035903930664
# EPISODE #: 18
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 18 165.45538330078125
# EPISODE #: 19
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 19 233.5712127685547
# EPISODE #: 20
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 20 323.87481689453125
# EPISODE #: 21
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 21 424.04827880859375
# EPISODE #: 22
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 22 527.545654296875
# EPISODE #: 23
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 23 638.2136840820312
# EPISODE #: 24
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 24 756.5348510742188
# EPISODE #: 25
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 25 884.8544921875
# EPISODE #: 26
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 26 1003.8262939453125
# EPISODE #: 27
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 27 1114.8450927734375
# EPISODE #: 28
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 28 1214.328369140625
# EPISODE #: 29
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 29 1305.724853515625
# ITER:  3
# EPISODE #: 0
# new state
# new state
# new state
# new state
# new state
# 4
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 0 0
# EPISODE #: 1
# new state
# 1
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 1 0.05498252436518669
# EPISODE #: 2
# new state
# 10001
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 2 0.19075770676136017
# EPISODE #: 3
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 3 4.019236087799072
# EPISODE #: 4
# new state
# 10001
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 4 9.210748672485352
# EPISODE #: 5
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 5 18.927114486694336
# EPISODE #: 6
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 6 34.85249328613281
# EPISODE #: 7
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 7 57.51736068725586
# EPISODE #: 8
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 8 87.62703704833984
# EPISODE #: 9
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 9 124.62896728515625
# EPISODE #: 10
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 10 168.61180114746094
# EPISODE #: 11
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 11 209.7710418701172
# EPISODE #: 12
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 12 257.5320129394531
# EPISODE #: 13
# new state
# 10001
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 13 302.4233093261719
# EPISODE #: 14
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 14 354.0718078613281
# EPISODE #: 15
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 15 402.29620361328125
# EPISODE #: 16
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 16 458.35699462890625
# EPISODE #: 17
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 17 510.0328369140625
# EPISODE #: 18
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 18 570.2886352539062
# EPISODE #: 19
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 19 638.4454956054688
# EPISODE #: 20
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 20 714.5536499023438
# EPISODE #: 21
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 21 786.62939453125
# EPISODE #: 22
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 22 868.4710693359375
# EPISODE #: 23
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 23 956.4345092773438
# EPISODE #: 24
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 24 1052.39453125
# EPISODE #: 25
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 25 1140.7073974609375
# EPISODE #: 26
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 26 1237.9398193359375
# EPISODE #: 27
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 27 1345.9449462890625
# EPISODE #: 28
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 28 1461.803466796875
# EPISODE #: 29
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 29 1583.1964111328125
# ITER:  4
# EPISODE #: 0
# new state
# new state
# new state
# new state
# new state
# 4
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 0 -0.03632568567991257
# EPISODE #: 1
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 1 -0.017485257238149643
# EPISODE #: 2
# new state
# new state
# 10002
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 2 -0.0025201551616191864
# EPISODE #: 3
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 3 2.714864730834961
# EPISODE #: 4
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 4 2.909761428833008
# EPISODE #: 5
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 5 1.3707562685012817
# EPISODE #: 6
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 6 -1.606187343597412
# EPISODE #: 7
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 7 -3.371384382247925
# EPISODE #: 8
# new state
# 10001
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 8 -4.7190752029418945
# EPISODE #: 9
# new state
# 10001
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 9 8.849137306213379
# EPISODE #: 10
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 10 26.224802017211914
# EPISODE #: 11
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 11 40.75089645385742
# EPISODE #: 12
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 12 53.56221008300781
# EPISODE #: 13
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 13 64.1447525024414
# EPISODE #: 14
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 14 73.08696746826172
# EPISODE #: 15
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 15 80.88079833984375
# EPISODE #: 16
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 16 88.01726531982422
# EPISODE #: 17
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 17 94.60382843017578
# EPISODE #: 18
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 18 100.4544448852539
# EPISODE #: 19
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 19 105.82733154296875
# EPISODE #: 20
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 20 110.39938354492188
# EPISODE #: 21
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 21 132.94155883789062
# EPISODE #: 22
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 22 154.8385467529297
# EPISODE #: 23
# 10000
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 23 191.2564239501953
# EPISODE #: 24
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 24 244.7764892578125
# EPISODE #: 25
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 25 302.709716796875
# EPISODE #: 26
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 26 365.55487060546875
# EPISODE #: 27
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 27 433.712646484375
# EPISODE #: 28
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 28 492.1142883300781
# EPISODE #: 29
# 0
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 29 546.853515625

# %%
df2 = pd.DataFrame(data, columns=COLUMNS)
print(df2)

df2.to_csv("/content/drive/MyDrive/CS 394R - 2024/Data/episodic_5_long.csv")
#a = df.to_csv()
# Out:
#     Run #  Training Loss  Testing Loss 42  Testing Loss 0  Test Seed 42 Score  \
# 0       0       0.303428                0               0                   0
# 1       0      53.052570                0               0                   0
# 2       0       0.232364                0               0                   0
# 3       0       0.696406                0               0                   0
# 4       0       1.236478             1000               0                   1
# ..    ...            ...              ...             ...                 ...
# 145     4   10988.216797                0            1000                   0
# 146     4    3897.392578                0            1000                   0
# 147     4   11665.466797                0               0                   0
# 148     4     131.191986                0               0                   0
# 149     4      51.064827                0               0                   0
#
#      Test Seed 0 Score  Returns  Take Coin QValue
# 0                    0        3          0.014482
# 1                    0        0         -1.072500
# 2                    0        1          0.145519
# 3                    0        0         -0.022669
# 4                    0        0         -0.073535
# ..                 ...      ...               ...
# 145                  1        0        302.709717
# 146                  1        0        365.554871
# 147                  0        0        433.712646
# 148                  0        0        492.114288
# 149                  0        0        546.853516
#
# [150 rows x 8 columns]

# %%
# Out:
# <__main__.TextAgent_Counter_Cumulative object at 0x7a1f592fc610>

# %% [markdown]
# ###### PER:

# %%
print(TRAIN_ENV[0])
per_data = []
for i in range(5):
  print("ITER: ", i)
  trained_agent, training_data = train_per(TRAIN_ENV[1], str(i), NUM_EPOCHS, HORIZON, 10000, 1000, 0.9)
  per_data.extend(training_data)
# Out:
# tw-v0
# ITER:  0
# EPISODE #: 0
# new state
# new state
# new state
# new state
# REPLAY:
# new state
# new state
# new state
# new state
# new state
# new state
# 1003.1666666666666
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 0 0.04983143135905266
# EPISODE #: 1
# REPLAY:
# new state
# new state
# REPLAY:
# new state
# 2.501190476190476
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 1 6.6417083740234375
# EPISODE #: 2
# REPLAY:
# 1001.3277777777778
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 2 1.526358723640442
# EPISODE #: 3
# REPLAY:
# REPLAY:
# 0.9050536881419234
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 3 0.41571325063705444
# EPISODE #: 4
# REPLAY:
# REPLAY:
# 1000.9241452991454
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 4 2.158449649810791
# EPISODE #: 5
# REPLAY:
# new state
# 1000.968253968254
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 5 3.4558427333831787
# EPISODE #: 6
# REPLAY:
# REPLAY:
# 0.89506882006882
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 6 2.035924196243286
# EPISODE #: 7
# REPLAY:
# REPLAY:
# 0.5267289372084768
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 7 0.6876777410507202
# EPISODE #: 8
# REPLAY:
# 1000.6386494252874
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 8 -0.24671509861946106
# EPISODE #: 9
# REPLAY:
# REPLAY:
# 0.5452394244015136
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 9 -0.4960803985595703
# EPISODE #: 10
# REPLAY:
# REPLAY:
# 0.45471872276405195
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 10 -0.4983857572078705
# EPISODE #: 11
# REPLAY:
# REPLAY:
# 0.33743098633671925
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 11 -0.3610295355319977
# EPISODE #: 12
# REPLAY:
# 1000.4065934065934
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 12 -0.15562890470027924
# EPISODE #: 13
# REPLAY:
# REPLAY:
# 0.3474013750025489
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 13 0.061056770384311676
# EPISODE #: 14
# REPLAY:
# REPLAY:
# 0.3780848021479083
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 14 0.14849454164505005
# EPISODE #: 15
# REPLAY:
# new state
# REPLAY:
# 1000.7941157519729
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 15 0.1585303097963333
# EPISODE #: 16
# REPLAY:
# REPLAY:
# 0.2712230877087026
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 16 0.1107441633939743
# EPISODE #: 17
# REPLAY:
# REPLAY:
# 0.23749677920269824
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 17 0.013357777148485184
# EPISODE #: 18
# REPLAY:
# 1000.5410073257865
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 18 -0.18345852196216583
# EPISODE #: 19
# REPLAY:
# REPLAY:
# 0.19394238400150726
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 19 -0.3283675014972687
# EPISODE #: 20
# REPLAY:
# REPLAY:
# 0.17648704128003717
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 20 -0.4276096820831299
# EPISODE #: 21
# REPLAY:
# REPLAY:
# 0.3032618040091932
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 21 -0.49192386865615845
# EPISODE #: 22
# REPLAY:
# REPLAY:
# 0.15577172028163044
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 22 -0.4919053316116333
# EPISODE #: 23
# REPLAY:
# REPLAY:
# 0.24828843643805196
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 23 -0.43863120675086975
# EPISODE #: 24
# REPLAY:
# REPLAY:
# 0.15959242195462967
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 24 -0.34891101717948914
# EPISODE #: 25
# REPLAY:
# REPLAY:
# 0.13124954346895873
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 25 -0.24470116198062897
# EPISODE #: 26
# REPLAY:
# REPLAY:
# 0.11634613850473681
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 26 -0.12432974576950073
# EPISODE #: 27
# REPLAY:
# REPLAY:
# 0.13607564556445723
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 27 0.0012867636978626251
# EPISODE #: 28
# REPLAY:
# REPLAY:
# 0.13193549557960163
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 28 0.07274755835533142
# EPISODE #: 29
# REPLAY:
# REPLAY:
# 0.12025958139023867
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 29 0.1251404881477356
# ITER:  1
# EPISODE #: 0
# new state
# new state
# new state
# REPLAY:
# new state
# new state
# new state
# REPLAY:
# 2.8428571428571425
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 0 0
# EPISODE #: 1
# REPLAY:
# new state
# new state
# REPLAY:
# new state
# new state
# 2.488888888888889
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 1 -0.19690214097499847
# EPISODE #: 2
# new state
# new state
# REPLAY:
# 1001.540909090909
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 2 1.087648630142212
# EPISODE #: 3
# REPLAY:
# new state
# 1001.6745421245421
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 3 0.20433054864406586
# EPISODE #: 4
# REPLAY:
# new state
# REPLAY:
# 0.7223428317468565
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 4 1.4474228620529175
# EPISODE #: 5
# REPLAY:
# REPLAY:
# 0.4907361775315066
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 5 1.3500345945358276
# EPISODE #: 6
# REPLAY:
# REPLAY:
# 0.386579714117014
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 6 0.2784094214439392
# EPISODE #: 7
# REPLAY:
# REPLAY:
# 1000.9288174788175
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 7 0.8831323385238647
# EPISODE #: 8
# REPLAY:
# REPLAY:
# 0.3469151414690317
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 8 0.35860294103622437
# EPISODE #: 9
# REPLAY:
# REPLAY:
# 0.5951949486323929
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 9 0.7101162672042847
# EPISODE #: 10
# REPLAY:
# REPLAY:
# 1000.8012555022009
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 10 1.3480080366134644
# EPISODE #: 11
# REPLAY:
# new state
# 1000.9996517809676
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 11 0.875645637512207
# EPISODE #: 12
# REPLAY:
# REPLAY:
# 0.33950471869450777
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 12 0.34669196605682373
# EPISODE #: 13
# REPLAY:
# REPLAY:
# 1000.6304998599602
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 13 0.1865662932395935
# EPISODE #: 14
# REPLAY:
# 1000.5498062953995
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 14 0.45642080903053284
# EPISODE #: 15
# REPLAY:
# REPLAY:
# 0.2429754234918587
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 15 0.6528249979019165
# EPISODE #: 16
# REPLAY:
# REPLAY:
# 0.3539693932335979
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 16 0.6962798833847046
# EPISODE #: 17
# REPLAY:
# REPLAY:
# 1000.4122604269144
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 17 0.6540482044219971
# EPISODE #: 18
# REPLAY:
# REPLAY:
# 0.19422216060722838
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 18 0.5787444114685059
# EPISODE #: 19
# REPLAY:
# REPLAY:
# 0.17701994637648644
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 19 0.48331284523010254
# EPISODE #: 20
# REPLAY:
# REPLAY:
# 0.1993968960438241
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 20 0.3629746735095978
# EPISODE #: 21
# REPLAY:
# REPLAY:
# 0.1565501266454309
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 21 0.224309504032135
# EPISODE #: 22
# REPLAY:
# REPLAY:
# 0.17802176217993051
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 22 0.0788607969880104
# EPISODE #: 23
# REPLAY:
# REPLAY:
# 0.2641823951754824
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 23 0.054397813975811005
# EPISODE #: 24
# REPLAY:
# REPLAY:
# 0.15915668643381017
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 24 0.03525790572166443
# EPISODE #: 25
# REPLAY:
# 1000.2829442470022
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 25 0.028008900582790375
# EPISODE #: 26
# REPLAY:
# REPLAY:
# 1000.2859664102539
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 26 0.04331279918551445
# EPISODE #: 27
# REPLAY:
# REPLAY:
# 0.12602200227362303
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 27 0.07203234732151031
# EPISODE #: 28
# REPLAY:
# REPLAY:
# 0.11640036081484087
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 28 0.19506025314331055
# EPISODE #: 29
# REPLAY:
# REPLAY:
# 0.15721274304650917
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 29 0.30580928921699524
# ITER:  2
# EPISODE #: 0
# new state
# new state
# new state
# REPLAY:
# new state
# new state
# new state
# new state
# REPLAY:
# 3.176190476190476
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 0 0
# EPISODE #: 1
# REPLAY:
# REPLAY:
# 1.142002442002442
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 1 1.4819278717041016
# EPISODE #: 2
# REPLAY:
# new state
# REPLAY:
# 1.0161398242280595
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 2 -0.41566669940948486
# EPISODE #: 3
# new state
# REPLAY:
# new state
# REPLAY:
# new state
# new state
# 2.4454887218045114
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 3 1.1848952770233154
# EPISODE #: 4
# REPLAY:
# REPLAY:
# 0.768986494466034
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 4 0.28014108538627625
# EPISODE #: 5
# REPLAY:
# REPLAY:
# 0.4345753950291156
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 5 -0.056175075471401215
# EPISODE #: 6
# REPLAY:
# new state
# 1001.3426115998697
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 6 -0.09931446611881256
# EPISODE #: 7
# REPLAY:
# REPLAY:
# 0.41927211570753775
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 7 -0.1992952823638916
# EPISODE #: 8
# REPLAY:
# REPLAY:
# 1000.7514405520984
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 8 -0.66552734375
# EPISODE #: 9
# REPLAY:
# REPLAY:
# 0.4307537963079472
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 9 -0.7635343074798584
# EPISODE #: 10
# REPLAY:
# REPLAY:
# 0.3734709437840499
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 10 -0.5528373718261719
# EPISODE #: 11
# REPLAY:
# REPLAY:
# 0.4880145819011365
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 11 -0.26000234484672546
# EPISODE #: 12
# REPLAY:
# REPLAY:
# 0.3287019153906412
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 12 -0.03410805016756058
# EPISODE #: 13
# REPLAY:
# REPLAY:
# 0.23409262913370402
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 13 -0.0024323202669620514
# EPISODE #: 14
# REPLAY:
# REPLAY:
# 0.31283949979651665
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 14 -0.030679110437631607
# EPISODE #: 15
# REPLAY:
# REPLAY:
# 0.20358575197466075
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 15 -0.010661251842975616
# EPISODE #: 16
# REPLAY:
# REPLAY:
# 0.21856282655855178
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 16 0.014534909278154373
# EPISODE #: 17
# REPLAY:
# REPLAY:
# 0.1749838886649295
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 17 0.025990057736635208
# EPISODE #: 18
# REPLAY:
# REPLAY:
# 0.19383469335564701
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 18 0.028541680425405502
# EPISODE #: 19
# REPLAY:
# REPLAY:
# 0.15357048917633992
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 19 0.052390605211257935
# EPISODE #: 20
# REPLAY:
# REPLAY:
# 0.14276545062717153
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 20 0.08486978709697723
# EPISODE #: 21
# REPLAY:
# REPLAY:
# 0.13695636784270643
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 21 0.11953561753034592
# EPISODE #: 22
# REPLAY:
# REPLAY:
# 0.12346883287190129
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 22 0.1506378948688507
# EPISODE #: 23
# REPLAY:
# REPLAY:
# 0.11811961244879418
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 23 0.17395849525928497
# EPISODE #: 24
# REPLAY:
# REPLAY:
# 0.41220568367517685
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 24 0.19026166200637817
# EPISODE #: 25
# REPLAY:
# REPLAY:
# 0.2720332913745551
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 25 0.19995057582855225
# EPISODE #: 26
# REPLAY:
# REPLAY:
# 0.10941590325291825
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 26 0.19411608576774597
# EPISODE #: 27
# REPLAY:
# new state
# 1000.6424668521443
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 27 0.1880788505077362
# EPISODE #: 28
# REPLAY:
# REPLAY:
# 1000.3380425512775
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 28 0.2008734494447708
# EPISODE #: 29
# REPLAY:
# REPLAY:
# 0.4029479445748839
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 29 0.20247599482536316
# ITER:  3
# EPISODE #: 0
# new state
# new state
# new state
# REPLAY:
# new state
# new state
# new state
# new state
# new state
# REPLAY:
# new state
# new state
# 3.6666666666666665
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 0 0
# EPISODE #: 1
# REPLAY:
# REPLAY:
# 1.4794011544011543
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 1 -1.9401240348815918
# EPISODE #: 2
# REPLAY:
# REPLAY:
# 1.180728993228993
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 2 -0.21002691984176636
# EPISODE #: 3
# REPLAY:
# new state
# REPLAY:
# 1.3840741559781806
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 3 0.6410472393035889
# EPISODE #: 4
# REPLAY:
# REPLAY:
# 0.5424398929194325
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 4 2.064173698425293
# EPISODE #: 5
# REPLAY:
# REPLAY:
# 0.49946800092978594
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 5 2.2243218421936035
# EPISODE #: 6
# REPLAY:
# new state
# REPLAY:
# 0.9124754401608621
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 6 1.4623359441757202
# EPISODE #: 7
# REPLAY:
# REPLAY:
# 0.37642686208475684
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 7 0.8102043867111206
# EPISODE #: 8
# REPLAY:
# REPLAY:
# 0.30655276249686286
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 8 0.399987131357193
# EPISODE #: 9
# REPLAY:
# REPLAY:
# 0.3213588321618883
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 9 0.10882142186164856
# EPISODE #: 10
# REPLAY:
# REPLAY:
# 0.8049606431185378
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 10 0.04427388310432434
# EPISODE #: 11
# REPLAY:
# REPLAY:
# 0.5377507129232854
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 11 0.309667706489563
# EPISODE #: 12
# REPLAY:
# REPLAY:
# 0.2849003694176632
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 12 0.4144902229309082
# EPISODE #: 13
# REPLAY:
# REPLAY:
# 0.2771334345529952
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 13 0.4470354914665222
# EPISODE #: 14
# REPLAY:
# REPLAY:
# 0.26794875566014537
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 14 0.40546417236328125
# EPISODE #: 15
# REPLAY:
# REPLAY:
# 0.2761410345541806
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 15 0.3376721441745758
# EPISODE #: 16
# REPLAY:
# REPLAY:
# 0.38964585717929956
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 16 0.250034362077713
# EPISODE #: 17
# REPLAY:
# REPLAY:
# 0.4078102599155231
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 17 0.1478661745786667
# EPISODE #: 18
# REPLAY:
# REPLAY:
# 0.34493041942040975
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 18 0.052845198661088943
# EPISODE #: 19
# REPLAY:
# REPLAY:
# 0.24502032678258756
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 19 -0.029709067195653915
# EPISODE #: 20
# REPLAY:
# REPLAY:
# 0.15329288811969677
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 20 -0.09681911766529083
# EPISODE #: 21
# REPLAY:
# REPLAY:
# 0.12517755717771673
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 21 -0.1345398873090744
# EPISODE #: 22
# REPLAY:
# REPLAY:
# 0.1447008289920661
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 22 -0.1579960137605667
# EPISODE #: 23
# REPLAY:
# REPLAY:
# 0.11168285398764823
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 23 -0.1718188375234604
# EPISODE #: 24
# REPLAY:
# REPLAY:
# 0.14515386794407475
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 24 -0.174165278673172
# EPISODE #: 25
# REPLAY:
# REPLAY:
# 0.1020216646054008
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 25 -0.1635153740644455
# EPISODE #: 26
# new state
# REPLAY:
# 1000.611569884364
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 26 -0.14561225473880768
# EPISODE #: 27
# REPLAY:
# REPLAY:
# 0.15529203670863573
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 27 -0.08137907087802887
# EPISODE #: 28
# REPLAY:
# REPLAY:
# 0.15507142387120604
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 28 -0.056861694902181625
# EPISODE #: 29
# REPLAY:
# REPLAY:
# 0.1285328726002154
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 29 -0.012550905346870422
# ITER:  4
# EPISODE #: 0
# new state
# new state
# new state
# new state
# new state
# new state
# REPLAY:
# new state
# new state
# new state
# new state
# new state
# 1002.5
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 0 -0.008121039718389511
# EPISODE #: 1
# REPLAY:
# REPLAY:
# 2.65
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 1 -1.1822316646575928
# EPISODE #: 2
# new state
# REPLAY:
# new state
# REPLAY:
# 2.3027777777777776
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 2 -0.6002666354179382
# EPISODE #: 3
# REPLAY:
# REPLAY:
# 1.200793650793651
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 3 5.012851715087891
# EPISODE #: 4
# REPLAY:
# REPLAY:
# 1.073026973026973
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 4 2.4536983966827393
# EPISODE #: 5
# REPLAY:
# REPLAY:
# 0.691217013121038
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 5 1.098224401473999
# EPISODE #: 6
# REPLAY:
# REPLAY:
# 0.5480689917760855
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 6 0.3448205292224884
# EPISODE #: 7
# REPLAY:
# REPLAY:
# 0.42791456530586963
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 7 0.005086700432002544
# EPISODE #: 8
# REPLAY:
# new state
# 1000.8296798029556
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 8 -0.4729362726211548
# EPISODE #: 9
# REPLAY:
# REPLAY:
# 0.3698478071580539
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 9 -0.5493560433387756
# EPISODE #: 10
# REPLAY:
# REPLAY:
# 0.3009181978222226
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 10 -0.37534260749816895
# EPISODE #: 11
# REPLAY:
# REPLAY:
# 0.5085299488701286
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 11 -0.19391122460365295
# EPISODE #: 12
# REPLAY:
# REPLAY:
# 0.3175215820806681
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 12 -0.058782219886779785
# EPISODE #: 13
# REPLAY:
# REPLAY:
# 0.273930091925762
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 13 0.002332712057977915
# EPISODE #: 14
# REPLAY:
# REPLAY:
# 0.22494360689903653
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 14 -0.019211875274777412
# EPISODE #: 15
# REPLAY:
# 1000.5252088546691
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 15 -0.0762605145573616
# EPISODE #: 16
# REPLAY:
# REPLAY:
# 0.23046708890886783
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 16 -0.07162605971097946
# EPISODE #: 17
# REPLAY:
# REPLAY:
# 0.293763849588084
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 17 -0.01795775629580021
# EPISODE #: 18
# REPLAY:
# REPLAY:
# 0.27209046080348687
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 18 0.09087806195020676
# EPISODE #: 19
# REPLAY:
# REPLAY:
# 0.2385472415645451
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 19 0.20869244635105133
# EPISODE #: 20
# REPLAY:
# REPLAY:
# 0.21209194082346558
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 20 0.3209937810897827
# EPISODE #: 21
# REPLAY:
# REPLAY:
# 0.2042836626449624
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 21 0.39306095242500305
# EPISODE #: 22
# REPLAY:
# REPLAY:
# 0.21422624947250302
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 22 0.4346644878387451
# EPISODE #: 23
# REPLAY:
# 1000.2181223376407
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 23 0.4509503245353699
# EPISODE #: 24
# REPLAY:
# REPLAY:
# 1000.3143106283463
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 24 0.42348095774650574
# EPISODE #: 25
# REPLAY:
# 1000.2836643588527
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 25 0.3790271580219269
# EPISODE #: 26
# REPLAY:
# REPLAY:
# new state
# 1000.6976517647229
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 26 0.3151187300682068
# EPISODE #: 27
# REPLAY:
# 1000.1848210097436
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 27 0.23027345538139343
# EPISODE #: 28
# REPLAY:
# 1000.1717716749271
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 28 0.13248857855796814
# EPISODE #: 29
# REPLAY:
# REPLAY:
# 0.13506349221905484
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 29 0.026286842301487923

# %%
df4 = pd.DataFrame(per_data, columns=COLUMNS)
print(df4)

df4.to_csv("/content/drive/MyDrive/CS 394R - 2024/Data/per_5_long.csv")
#a = df.to_csv()
# Out:
#     Run #  Training Loss  Testing Loss 42  Testing Loss 0  Test Seed 42 Score  \
# 0       0       0.128082                0               0                   0
# 1       0      20.726231                0               0                   0
# 2       0       2.463628                0               0                   0
# 3       0       1.065155                0               0                   0
# 4       0       5.896615                0               0                   0
# ..    ...            ...              ...             ...                 ...
# 145     4       0.022060                0            1000                   0
# 146     4       0.028152                0            1000                   0
# 147     4       0.005789                0            1000                   0
# 148     4       0.002736                0            1000                   0
# 149     4       0.002800                0               0                   0
#
#      Test Seed 0 Score      Returns  Take Coin QValue
# 0                    0  1003.166667          0.049831
# 1                    0     2.501190          6.641708
# 2                    0  1001.327778          1.526359
# 3                    0     0.905054          0.415713
# 4                    0  1000.924145          2.158450
# ..                 ...          ...               ...
# 145                  1  1000.283664          0.379027
# 146                  1  1000.697652          0.315119
# 147                  1  1000.184821          0.230273
# 148                  1  1000.171772          0.132489
# 149                  0     0.135063          0.026287
#
# [150 rows x 8 columns]

# %% [markdown]
# ##### PSER

# %%
print(TRAIN_ENV[0])
pser_data = []
for i in range(5):
  print("ITER: ", i)
  trained_agent, training_data = train_pser(TRAIN_ENV[1], str(i), NUM_EPOCHS, HORIZON, 10000, 1000, 0.9)
  pser_data.extend(training_data)
# Out:
# tw-v0
# ITER:  0
# EPISODE #: 0
# new state
# new state
# new state
# new state
# new state
# 3.833333333333334
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 0 -0.019253617152571678
# EPISODE #: 1
# new state
# 2.019047619047619
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 1 0.746414303779602
# EPISODE #: 2
# 1.130963480963481
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 2 -0.11228758841753006
# EPISODE #: 3
# 1.4537087912087912
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 3 1.3352429866790771
# EPISODE #: 4
# 0.7965741559781807
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 4 0.14190752804279327
# EPISODE #: 5
# 0.6408125932038975
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 5 0.0738343670964241
# EPISODE #: 6
# new state
# 1001.13895173454
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 6 -0.029514720663428307
# EPISODE #: 7
# 0.4120089121120014
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 7 0.44416236877441406
# EPISODE #: 8
# 0.39660887315299087
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 8 0.3730359673500061
# EPISODE #: 9
# REPLAYING:  [0]
# new state
# new state
# new state
# new state
# new state
# Replay score:  1002.8333333333334
# EPISODE #: 9
# 0.3930037975779122
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 9 -0.24674764275550842
# EPISODE #: 10
# 0.3228149745996055
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 10 -0.34888845682144165
# EPISODE #: 11
# REPLAYING:  [0]
# Replay score:  1001.3333333333334
# EPISODE #: 11
# 0.7130095116155278
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 11 -0.18799878656864166
# EPISODE #: 12
# 0.3658991522643596
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 12 -0.03242485225200653
# EPISODE #: 13
# REPLAYING:  [0]
# Replay score:  1000.9000000000001
# EPISODE #: 13
# 0.2551427947726971
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 13 0.16375762224197388
# EPISODE #: 14
# 1000.490108794714
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 14 0.18599487841129303
# EPISODE #: 15
# REPLAYING:  [0]
# Replay score:  1000.6607142857142
# EPISODE #: 15
# new state
# 1000.746699829357
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 15 0.05385708808898926
# EPISODE #: 16
# REPLAYING:  [1]
# new state
# Replay score:  1001.0194444444444
# EPISODE #: 16
# 0.6768025637115734
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 16 0.2289518564939499
# EPISODE #: 17
# 0.21979094497649782
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 17 0.32230162620544434
# EPISODE #: 18
# REPLAYING:  [2]
# Replay score:  1000.5880952380953
# EPISODE #: 18
# 1000.4204882836461
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 18 0.07863080501556396
# EPISODE #: 19
# REPLAYING:  [2]
# Replay score:  1000.4248376623377
# EPISODE #: 19
# 0.2803491572391056
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 19 0.21807074546813965
# EPISODE #: 20
# 0.18322521701464628
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 20 0.2766149938106537
# EPISODE #: 21
# REPLAYING:  [0]
# Replay score:  1000.3894230769231
# EPISODE #: 21
# 0.17247507406912282
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 21 0.32298529148101807
# EPISODE #: 22
# 0.17478445316939023
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 22 0.3015346825122833
# EPISODE #: 23
# REPLAYING:  [2]
# Replay score:  1000.3436507936508
# EPISODE #: 23
# 0.15450770983410653
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 23 0.1376802623271942
# EPISODE #: 24
# 1000.2747916334873
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 24 0.04224413260817528
# EPISODE #: 25
# REPLAYING:  [1]
# Replay score:  1000.544696969697
# EPISODE #: 25
# 0.2916231478918204
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 25 0.38509318232536316
# EPISODE #: 26
# 0.1536832880208942
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 26 0.13308453559875488
# EPISODE #: 27
# REPLAYING:  [3]
# Replay score:  1000.2892732267732
# EPISODE #: 27
# 0.13332196079856673
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 27 0.2594628632068634
# EPISODE #: 28
# 0.13028471094929955
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 28 0.3904206454753876
# EPISODE #: 29
# REPLAYING:  [3]
# Replay score:  1000.2612044817927
# EPISODE #: 29
# 0.12124151845316523
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 29 0.564601719379425
# ITER:  1
# EPISODE #: 0
# new state
# new state
# new state
# new state
# 3.3666666666666667
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 0 0
# EPISODE #: 1
# 1.5532106782106783
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 1 0
# EPISODE #: 2
# new state
# new state
# 1.7773199023199022
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 2 -0.04534805566072464
# EPISODE #: 3
# 0.8493880087920336
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 3 -0.44311994314193726
# EPISODE #: 4
# 1.131307098698403
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 4 -2.9154350757598877
# EPISODE #: 5
# 0.5078538509420862
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 5 -1.4174909591674805
# EPISODE #: 6
# 0.4648540038157888
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 6 -0.73160719871521
# EPISODE #: 7
# 0.8607510429491854
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 7 -0.09857259690761566
# EPISODE #: 8
# 1.3814745196324143
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 8 0.28155094385147095
# EPISODE #: 9
# 0.34576967337084724
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 9 0.48176640272140503
# EPISODE #: 10
# 0.30348967654471815
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 10 0.7525516152381897
# EPISODE #: 11
# new state
# 1000.8944987650233
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 11 1.0742440223693848
# EPISODE #: 12
# 0.4106303272987692
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 12 1.2012193202972412
# EPISODE #: 13
# REPLAYING:  [0]
# new state
# new state
# new state
# new state
# new state
# new state
# Replay score:  1003.5
# EPISODE #: 13
# 0.4061897717470473
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 13 1.1522184610366821
# EPISODE #: 14
# 0.4356735359361522
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 14 0.8261664509773254
# EPISODE #: 15
# REPLAYING:  [0]
# Replay score:  1001.6
# EPISODE #: 15
# 0.33134346439967927
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 15 0.5356245636940002
# EPISODE #: 16
# 0.39959248442120493
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 16 0.5143228769302368
# EPISODE #: 17
# REPLAYING:  [0]
# Replay score:  1001.0728174603175
# EPISODE #: 17
# 0.2946974553476414
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 17 0.8305705189704895
# EPISODE #: 18
# 0.19299532478604653
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 18 1.0806217193603516
# EPISODE #: 19
# REPLAYING:  [0]
# Replay score:  1000.8127164502164
# EPISODE #: 19
# 0.1812889890123048
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 19 1.5961430072784424
# EPISODE #: 20
# 0.18034060714501632
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 20 1.8220205307006836
# EPISODE #: 21
# REPLAYING:  [0]
# Replay score:  1000.6559218559219
# EPISODE #: 21
# 0.21059762742265214
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 21 2.1551477909088135
# EPISODE #: 22
# new state
# 1000.6846691104234
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 22 2.21985125541687
# EPISODE #: 23
# REPLAYING:  [1]
# Replay score:  1000.6897997835498
# EPISODE #: 23
# 0.24790549335009793
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 23 1.6930906772613525
# EPISODE #: 24
# 0.20380522450350932
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 24 1.432325005531311
# EPISODE #: 25
# REPLAYING:  [1]
# Replay score:  1000.5430717158658
# EPISODE #: 25
# 0.18553749795977406
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 25 0.9794330596923828
# EPISODE #: 26
# 1000.3458444802362
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 26 0.793256938457489
# EPISODE #: 27
# REPLAYING:  [1]
# Replay score:  1000.4169823232323
# EPISODE #: 27
# 0.33592977841098143
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 27 0.5342295169830322
# EPISODE #: 28
# 0.2901430777442516
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 28 0.43317079544067383
# EPISODE #: 29
# REPLAYING:  [1]
# Replay score:  1000.3620462354983
# EPISODE #: 29
# 0.23465682301043372
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 29 0.28922972083091736
# ITER:  2
# EPISODE #: 0
# new state
# new state
# new state
# 2.9
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 0 0
# EPISODE #: 1
# new state
# new state
# new state
# new state
# 1002.4107142857143
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 1 3.566190242767334
# EPISODE #: 2
# 1.5372766122766124
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 2 0.0963265523314476
# EPISODE #: 3
# REPLAYING:  [0]
# new state
# new state
# new state
# new state
# new state
# new state
# Replay score:  1003.0833333333334
# EPISODE #: 3
# 0.7772509353391708
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 3 4.060917854309082
# EPISODE #: 4
# new state
# 1001.8585839598998
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 4 4.560240745544434
# EPISODE #: 5
# 0.5728753833549229
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 5 1.8653100728988647
# EPISODE #: 6
# REPLAYING:  [1]
# Replay score:  1001.9583333333334
# EPISODE #: 6
# 0.6016230257609568
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 6 -0.5340216159820557
# EPISODE #: 7
# 0.6194001901063971
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 7 -0.8975955247879028
# EPISODE #: 8
# REPLAYING:  [0]
# Replay score:  1001.0166666666667
# EPISODE #: 8
# 0.6320834757905696
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 8 -1.1036854982376099
# EPISODE #: 9
# 1000.7940935672515
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 9 -0.946279764175415
# EPISODE #: 10
# REPLAYING:  [2]
# Replay score:  1000.7297619047619
# EPISODE #: 10
# 0.3778697465198726
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 10 -0.2153511345386505
# EPISODE #: 11
# 0.35407638977189854
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 11 0.009453929960727692
# EPISODE #: 12
# REPLAYING:  [1]
# Replay score:  1000.8609126984127
# EPISODE #: 12
# 0.34230125212648005
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 12 0.0678306445479393
# EPISODE #: 13
# 0.2715086162476045
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 13 -0.026421189308166504
# EPISODE #: 14
# REPLAYING:  [1]
# Replay score:  1000.689898989899
# EPISODE #: 14
# 0.23495654423618836
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 14 -0.22406139969825745
# EPISODE #: 15
# 0.5006667337229486
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 15 -0.29497724771499634
# EPISODE #: 16
# REPLAYING:  [1]
# Replay score:  1000.5757992007991
# EPISODE #: 16
# 0.42625168664756674
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 16 -0.35721510648727417
# EPISODE #: 17
# 0.21345830822278147
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 17 -0.3563541769981384
# EPISODE #: 18
# REPLAYING:  [0]
# Replay score:  1000.4227564102564
# EPISODE #: 18
# 0.1738258315340939
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 18 -0.2918124794960022
# EPISODE #: 19
# 0.14613495835553994
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 19 -0.23101750016212463
# EPISODE #: 20
# REPLAYING:  [2]
# Replay score:  1000.3499007936508
# EPISODE #: 20
# 0.20302788967425703
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 20 -0.10494408756494522
# EPISODE #: 21
# 0.19593664993703458
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 21 -0.03623711317777634
# EPISODE #: 22
# REPLAYING:  [0]
# Replay score:  1000.3433006535947
# EPISODE #: 22
# 0.16800128677786327
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 22 0.1885213553905487
# EPISODE #: 23
# 0.15612699124012636
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 23 0.3333188593387604
# EPISODE #: 24
# REPLAYING:  [2]
# Replay score:  1000.2861494198955
# EPISODE #: 24
# 0.15067877915148437
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 24 0.627515971660614
# EPISODE #: 25
# 0.25460738378653974
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 25 0.7666307687759399
# EPISODE #: 26
# REPLAYING:  [1]
# Replay score:  1000.3915204678362
# EPISODE #: 26
# 0.12900371787413528
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 26 0.9743230938911438
# EPISODE #: 27
# 0.12974303874842932
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 27 1.0559254884719849
# EPISODE #: 28
# REPLAYING:  [2]
# Replay score:  1000.2451714951716
# EPISODE #: 28
# 0.11474040693529883
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 28 1.1739088296890259
# EPISODE #: 29
# 0.11696464065785947
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 29 1.2410799264907837
# ITER:  3
# EPISODE #: 0
# new state
# new state
# new state
# 2.9
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 0 0
# EPISODE #: 1
# new state
# new state
# new state
# new state
# 1002.4107142857143
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 1 0.16288943588733673
# EPISODE #: 2
# new state
# 1001.6111111111111
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 2 0.130110964179039
# EPISODE #: 3
# 1.6087662337662336
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 3 0.10283543169498444
# EPISODE #: 4
# 0.8466953797836152
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 4 1.7712795734405518
# EPISODE #: 5
# REPLAYING:  [0]
# new state
# new state
# new state
# new state
# new state
# new state
# Replay score:  1003.0833333333334
# EPISODE #: 5
# 0.8228446991604885
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 5 0.4808824956417084
# EPISODE #: 6
# 0.5699126598039641
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 6 0.16021610796451569
# EPISODE #: 7
# REPLAYING:  [0]
# Replay score:  1001.5416666666666
# EPISODE #: 7
# 0.46900280980283016
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 7 0.5460723042488098
# EPISODE #: 8
# 0.7953737918092139
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 8 0.5563340783119202
# EPISODE #: 9
# REPLAYING:  [0]
# Replay score:  1001.0500000000001
# EPISODE #: 9
# 0.38401037907229857
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 9 0.015978384763002396
# EPISODE #: 10
# 0.2982118075596081
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 10 -0.0777188166975975
# EPISODE #: 11
# REPLAYING:  [1]
# Replay score:  1000.7797619047619
# EPISODE #: 11
# 0.2582737330967954
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 11 -0.2279149889945984
# EPISODE #: 12
# 0.3205792679269518
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 12 -0.2542324662208557
# EPISODE #: 13
# REPLAYING:  [1]
# Replay score:  1000.6125
# EPISODE #: 13
# 0.23352557290967113
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 13 -0.10867264866828918
# EPISODE #: 14
# 0.739762858519816
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 14 0.008709453046321869
# EPISODE #: 15
# REPLAYING:  [1]
# Replay score:  1000.5055555555556
# EPISODE #: 15
# 0.2694119550320501
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 15 0.08244065195322037
# EPISODE #: 16
# 0.16731631296313915
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 16 0.09177418798208237
# EPISODE #: 17
# REPLAYING:  [1]
# Replay score:  1000.4309523809524
# EPISODE #: 17
# 0.24124191540546708
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 17 0.10324108600616455
# EPISODE #: 18
# 0.19935268568147785
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 18 0.09896641969680786
# EPISODE #: 19
# REPLAYING:  [0]
# Replay score:  1000.5662878787879
# EPISODE #: 19
# 0.32030934200593486
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 19 0.09324280917644501
# EPISODE #: 20
# 0.1807857091318889
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 20 0.08937732130289078
# EPISODE #: 21
# REPLAYING:  [1]
# Replay score:  1000.3479853479853
# EPISODE #: 21
# 0.1240881516523051
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 21 0.24801701307296753
# EPISODE #: 22
# 0.14130393228054547
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 22 0.3454552888870239
# EPISODE #: 23
# REPLAYING:  [0]
# Replay score:  1000.4619047619047
# EPISODE #: 23
# 0.2767950755673226
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 23 0.4598289728164673
# EPISODE #: 24
# 0.15563064698472256
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 24 0.4618256688117981
# EPISODE #: 25
# REPLAYING:  [1]
# Replay score:  1000.2926136363636
# EPISODE #: 25
# 0.10126256747918437
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 25 0.33918389678001404
# EPISODE #: 26
# 0.1460330446216349
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 26 0.2575371563434601
# EPISODE #: 27
# REPLAYING:  [0]
# Replay score:  1000.3905228758169
# EPISODE #: 27
# 0.15973372698386945
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 27 0.08942116051912308
# EPISODE #: 28
# 0.27913825332782743
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 28 0.10520564019680023
# EPISODE #: 29
# REPLAYING:  [1]
# Replay score:  1000.2528115159694
# EPISODE #: 29
# 1000.2705325690464
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 1
# [0, 1000]
# [0, 1]
# Episode # 29 0.1026204526424408
# ITER:  4
# EPISODE #: 0
# new state
# new state
# new state
# new state
# 3.2333333333333334
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 0 0
# EPISODE #: 1
# 1.2155122655122654
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 1 -1.4173787832260132
# EPISODE #: 2
# 0.7501123876123876
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 2 -0.3564327657222748
# EPISODE #: 3
# new state
# new state
# new state
# 1002.1977124183006
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 3 -3.4027183055877686
# EPISODE #: 4
# 1.7913220551378444
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 4 -2.465789556503296
# EPISODE #: 5
# 0.48284823214356126
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 5 -1.763015866279602
# EPISODE #: 6
# REPLAYING:  [0]
# new state
# new state
# new state
# new state
# new state
# Replay score:  1002.8333333333334
# EPISODE #: 6
# 0.3880899646192
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 6 -0.2318427562713623
# EPISODE #: 7
# 1.0083854093934739
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 7 -0.6368030309677124
# EPISODE #: 8
# REPLAYING:  [0]
# Replay score:  1001.3333333333334
# EPISODE #: 8
# new state
# 1000.9683372183372
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 8 -0.8264556527137756
# EPISODE #: 9
# REPLAYING:  [1]
# Replay score:  1000.8666666666667
# EPISODE #: 9
# 1.028196313490431
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 9 -0.06395745277404785
# EPISODE #: 10
# 0.40967820506226615
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 10 -0.006505373865365982
# EPISODE #: 11
# REPLAYING:  [0]
# Replay score:  1000.7595238095239
# EPISODE #: 11
# 0.5999929593969842
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 11 0.19307538866996765
# EPISODE #: 12
# 0.40357367679296574
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 12 0.2305760681629181
# EPISODE #: 13
# REPLAYING:  [1]
# Replay score:  1000.575
# EPISODE #: 13
# 1000.4188367188368
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 13 0.02597080171108246
# EPISODE #: 14
# REPLAYING:  [2]
# Replay score:  1000.4444444444445
# EPISODE #: 14
# 0.28404651430392147
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 14 0.3301236629486084
# EPISODE #: 15
# 0.2545529684917053
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 15 0.4950466752052307
# EPISODE #: 16
# REPLAYING:  [2]
# Replay score:  1000.3857142857142
# EPISODE #: 16
# 0.23560469366445183
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 16 0.5479505062103271
# EPISODE #: 17
# 0.24451754895844208
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 17 0.44396325945854187
# EPISODE #: 18
# REPLAYING:  [1]
# Replay score:  1000.3409090909091
# EPISODE #: 18
# 1000.2939068100358
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 18 0.057250380516052246
# EPISODE #: 19
# REPLAYING:  [2]
# Replay score:  1000.2944444444445
# EPISODE #: 19
# 0.31402463176739603
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 19 0.3102652430534363
# EPISODE #: 20
# 0.19565784585416424
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 20 0.41549474000930786
# EPISODE #: 21
# REPLAYING:  [3]
# Replay score:  1000.2678321678322
# EPISODE #: 21
# 0.1792113667712067
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 21 0.4713476002216339
# EPISODE #: 22
# new state
# 1000.7227995097356
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 22 0.3866419792175293
# EPISODE #: 23
# 0.21115785384547403
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 23 0.22065651416778564
# EPISODE #: 24
# REPLAYING:  [4]
# new state
# Replay score:  1001.3102543290044
# EPISODE #: 24
# 1000.2261930288063
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 0
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [0, 0]
# [0, 0]
# Episode # 24 0.042309388518333435
# EPISODE #: 25
# REPLAYING:  [4]
# Replay score:  1000.7418386652906
# EPISODE #: 25
# 1000.3335370265179
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 25 0.2606237530708313
# EPISODE #: 26
# 0.1518933307491392
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 26 0.352839857339859
# EPISODE #: 27
# REPLAYING:  [6]
# Replay score:  1000.3998397435897
# EPISODE #: 27
# 1000.3861299398882
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 27 0.5098416209220886
# EPISODE #: 28
# 0.13743774764249725
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 28 0.5613146424293518
# EPISODE #: 29
# 0.13120348509881447
# Testing:
# Testing:  tw-v1
# Results for:  tw-v1 0 1
# Testing:  tw-v0
# Results for:  tw-v1 0 0
# [1000, 0]
# [1, 0]
# Episode # 29 0.60584557056427

# %%
df3 = pd.DataFrame(pser_data, columns=COLUMNS)
#print(df2)

df3.to_csv("/content/drive/MyDrive/CS 394R - 2024/Data/pser_5_long.csv")
#a = df.to_csv()

# %% [markdown]
# ### Agent with Episodic Bonus Demo:

# %%
try:
    trained_agent.set_test()
    done = False
    obs, infos  = TRAIN_ENV[1].reset()
    TRAIN_ENV[1].render()
    obs, score, done, infos = TRAIN_ENV[1].step('look')
    num_moves = 0
    while not done:
        TRAIN_ENV[1].render()
        q_values, _ = trained_agent.get_qvals(obs, infos, score)
        action, value = trained_agent.get_max_qval(q_values, infos)
        obs, score, done, infos = TRAIN_ENV[1].step(action)
        num_moves+=1
        time.sleep(3)

    TRAIN_ENV[1].render()  # Final message.
    trained_agent.set_train()
except KeyboardInterrupt:
    pass  # Quit the game.

print("Played {} steps, scoring {} points.".format(num_moves, score))
# Out:
#                     ________  ________  __    __  ________
#                    |        \|        \|  \  |  \|        \
#                     \$$$$$$$$| $$$$$$$$| $$  | $$ \$$$$$$$$
#                       | $$   | $$__     \$$\/  $$   | $$
#                       | $$   | $$  \     >$$  $$    | $$
#                       | $$   | $$$$$    /  $$$$\    | $$
#                       | $$   | $$_____ |  $$ \$$\   | $$
#                       | $$   | $$     \| $$  | $$   | $$
#                        \$$    \$$$$$$$$ \$$   \$$    \$$
#               __       __   ______   _______   __        _______
#              |  \  _  |  \ /      \ |       \ |  \      |       \
#              | $$ / \ | $$|  $$$$$$\| $$$$$$$\| $$      | $$$$$$$\
#              | $$/  $\| $$| $$  | $$| $$__| $$| $$      | $$  | $$
#              | $$  $$$\ $$| $$  | $$| $$    $$| $$      | $$  | $$
#              | $$ $$\$$\$$| $$  | $$| $$$$$$$\| $$      | $$  | $$
#              | $$$$  \$$$$| $$__/ $$| $$  | $$| $$_____ | $$__/ $$
#              | $$$    \$$$ \$$    $$| $$  | $$| $$     \| $$    $$
#               \$$      \$$  \$$$$$$  \$$   \$$ \$$$$$$$$ \$$$$$$$
#
# You are now playing a fast paced round of TextWorld! First stop, head west. With
# that over with, make an attempt to travel north. That done, venture east. And
# then, head north. Following that, lift the coin from the floor of the studio.
# That's it!
#
# -= Cellar =-
# You are in a cellar. A normal one.
#
#
#
# You don't like doors? Why not try going west, that entranceway is unguarded.
#
# > look
# -= Cellar =-
# You are in a cellar. A normal one.
#
#
#
# You don't like doors? Why not try going west, that entranceway is unguarded.
#
# > go west
#
# -= Shower =-
# You arrive in a shower. A standard kind of place.
#
#
#
# You need an unguarded exit? You should try going east. You don't like doors? Why
# not try going north, that entranceway is unguarded.
#
# > go north
#
# -= Laundromat =-
# You're now in a laundromat. You try to gain information on your surroundings by
# using a technique you call "looking."
#
#
#
# You need an unguarded exit? You should try going east. You don't like doors? Why
# not try going south, that entranceway is unguarded.
#
# > go east
#
# -= Chamber =-
# You arrive in a typical kind of place. That is to say, you're in a chamber. You
# begin to take stock of what's here.
#
#
#
# You don't like doors? Why not try going north, that entranceway is unguarded.
# You don't like doors? Why not try going west, that entranceway is unblocked.
#
# > go north
#
# -= Studio =-
# You are in a studio. A typical kind of place.
#
#
#
# There is an exit to the south. Don't worry, it is unguarded.
#
# There is a coin on the floor.
#
# > take coin
# You pick up the coin from the ground.
#
#
#
# Your score has just gone up by one point.
#
#
#                                *** The End ***
#
# You scored 1 out of a possible 1, in 7 turns.
#
#
# Would you like to RESTART, RESTORE a saved game, QUIT or UNDO the last command?
# >
#
# Played 5 steps, scoring 1 points.
